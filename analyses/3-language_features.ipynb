# %% [markdown]
# # 3) Language Models
#
# Models investigating the effect of spoken frequency, and concretneess, controlling for using word norms, including orthographic frequency norms and prescence of speech. </br>

# %%
from create import create_models
from pyns import Neuroscout
from matplotlib import pyplot as plt
from pathlib import Path
import sys
sys.path.append("..") 
from utils import dump_collection, load_collection

# %matplotlib inline
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
api = Neuroscout()

# %% [markdown]
# ## Define predictors and confounds

# %%
predictors = [
    'subtlexusfrequency_Lg10WF', 'speech', 'massiveauditorylexicaldecision_PhonLev', 'text_length', 
    'massiveauditorylexicaldecision_NumSylls', 'massiveauditorylexicaldecision_NumPhones', 
    'massiveauditorylexicaldecision_Duration', 'concreteness_Conc.M'
]
transform_variables = list(set(predictors) - set(['speech']))
datasets = api.datasets.get() # Get all Neuroscout datasets

# %%
confounds = ['a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'a_comp_cor_04', 'a_comp_cor_05', 'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z']

# %%
filename = Path('models') / 'lexical_variables.json'
language_models = load_collection(filename) # Load instead of re-running

# %% [markdown]
# ## Create models

# %%
transformations = [
    {"Name": "Scale", "Demean": True, "Rescale": True, "ReplaceNA": "after", "Input": [p],"Output": [p]} 
    for p in transform_variables
    ]

# %%
name = name = '+'.join(predictors)
# language_models = {}
# language_models[name] = create_models(name=name,
#     predictors=predictors, confounds=confounds, datasets=datasets, transformations=transformations)

# %%
analysis = language_models[name][0]['analysis']
analysis.generate_report(run_id=analysis.runs[0]) 
analysis.plot_report(plot_type='design_matrix_plot')
# Out:
# <div id="altair-viz-1"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     const outputDiv = document.getElementById("altair-viz-1");
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.0.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-58866f1413ed7f641addddcdb877ca5e"}, "datasets": {"data-58866f1413ed7f641addddcdb877ca5e": [{"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 0, "value": -2.4019126112667153e-09}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 1, "value": 4.1942051960896115e-09}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 2, "value": -5.327166229374929e-09}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 3, "value": -1.015204789272715e-09}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 4, "value": 4.1497464639935205e-08}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 5, "value": -2.0750579518406283e-07}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 6, "value": 7.896058504626256e-07}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 7, "value": -2.6676077768868506e-06}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 8, "value": 8.439240581823965e-06}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 9, "value": -2.5826984511072475e-05}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 10, "value": 7.199639640736977e-05}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 11, "value": -0.00015675957832438363}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 12, "value": -0.0006943627944333462}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 13, "value": -0.026890561216419702}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 14, "value": -0.1109086059817588}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 15, "value": -0.2134228983993257}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 16, "value": -0.2864705514648731}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 17, "value": -0.3326664846953967}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 18, "value": -0.3703554037640109}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 19, "value": -0.4253374238264603}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 20, "value": -0.5185449958706931}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 21, "value": -0.6362537517724949}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 22, "value": -0.7138509009449939}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 23, "value": -0.6908406649700409}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 24, "value": -0.5628911220312388}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 25, "value": -0.3893362805893965}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 26, "value": -0.2318732491537582}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 27, "value": -0.12202057382019925}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 28, "value": -0.06693896471393815}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 29, "value": -0.04302442575981861}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 30, "value": -0.025628463971016376}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 31, "value": -0.006034175525448691}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 32, "value": 0.0137354506911638}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 33, "value": 0.02940889258574969}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 34, "value": 0.03878018632744227}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 35, "value": 0.042097064599159705}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 36, "value": 0.040957093154671366}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 37, "value": 0.037194220589458836}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 38, "value": 0.032273792210092134}, {"regressor": "subtlexusfrequency_Lg1 ...

# %%
# dump_collection(language_models, filename)

# %% [markdown]
# ## Compile models

# %%
# Compile analyses
# for analysis_dict in language_models[name]:
#     analysis = analysis_dict['analysis']
#     if analysis.get_status()['status'] in 'DRAFT':
#         analysis.compile()
